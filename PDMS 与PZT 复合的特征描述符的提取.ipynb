# %%
def hs1(dic):
    num=[]
    k=[]
    h=[]
    e=[]
    zhouchang=[]
    yuandu=[]
    dic1=dic.copy()
    for x in range(1,500):
        for y in range(1,2):
            for z in range(1,500):
                
                if dic1[str(x)+','+str(y)+','+str(z)]==str(2):
                    lsz=[z]
                    lsy=[y]
                    m=0
                    lsx=[str(x)+','+str(y)+','+str(z)]
                    dic1[lsx[m]]=str(3)
                    while dic1[lsx[m]]==str(3):
                        q=lsx[m].split(',')
                        x=int(q[0])
                        y=int(q[1])
                        z=int(q[2])
                        if 0<y+1<=500:
                            a=x
                            b=y+1
                            c=z
                            if dic1[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic1[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(b)
                        if 0<y-1<=500:
                            a=x
                            b=y-1
                            c=z
                            if dic1[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic1[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(b)
                        if 0<z+1<=500:
                            a=x
                            b=y
                            c=z+1
                            if dic1[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic1[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(b)
                        if 0<z-1<=500:
                            a=x
                            b=y
                            c=z-1
                            if dic1[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic1[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(b)
                        m=m+1
                        if len(lsx)<m+1:
                            if len(lsx)>4:
                                d1=max(lsz)-min(lsz)+1
                                d2=max(lsy)-min(lsy)+1
                                p=d1/d2
                                k.append(p)
                                num.append(len(lsx))
                                h.append(d1)
                                g=d1/len(lsx)
                                e.append(g)
                                n=0
                                for i in range(len(lsx)):
                                    q=lsx[i].split(',')
                                    x=int(q[0])
                                    y=int(q[1])
                                    z=int(q[2])
                                    k1=y+1
                                    k2=y-1
                                    k3=z+1
                                    k4=z-1
                                    if 0<k1<=500 and dic1[str(x)+','+str(k1)+','+str(z)]==str(1):
                                        n=n+1
                                    if 0<k2<=500 and dic1[str(x)+','+str(k2)+','+str(z)]==str(1):
                                        n=n+1
                                    if 0<k3<=500 and dic1[str(x)+','+str(y)+','+str(k3)]==str(1):
                                        n=n+1
                                    if 0<k4<=500 and dic1[str(x)+','+str(y)+','+str(k4)]==str(1):
                                        n=n+1
                                zhouchang.append(n)
                                if n>0:
                                    yuan=4*pi*len(lsx)/n**2
                                    yuandu.append(yuan)
                            break
    return k,num,h,e,zhouchang,yuandu
#yz平面 dz/dy  取向因子：dz/dy的大小  核的面积 核的高度 核的高度与核的面积之比  核的周长 核的圆度

# %%
def hs2(dic):
    num=[]
    k=[]
    h=[]
    e=[]
    zhouchang=[]
    yuandu=[]
    dic2=dic.copy()
    for x in range(1,65):
        for y in range(1,65):
            for z in range(1,65):
                if dic2[str(x)+','+str(y)+','+str(z)]==str(2):
                    lsz=[z]
                    lsy=[x]
                    m=0
                    lsx=[str(x)+','+str(y)+','+str(z)]
                    dic2[lsx[m]]=str(3)
                    while dic2[lsx[m]]==str(3):
                        q=lsx[m].split(',')
                        x=int(q[0])
                        y=int(q[1])
                        z=int(q[2])
                        if 0<x+1<=64:
                            a=x+1
                            b=y
                            c=z
                            if dic2[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic2[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(a)
                        if 0<x-1<=64:
                            a=x-1
                            b=y
                            c=z
                            if dic2[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic2[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(a)
                        if 0<z+1<=64:
                            a=x
                            b=y
                            c=z+1
                            if dic2[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic2[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(a)
                        if 0<z-1<=64:
                            a=x
                            b=y
                            c=z-1
                            if dic2[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic2[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                                lsy.append(a)
                        m=m+1
                        if len(lsx)<m+1:
                            if len(lsx)>4:
                                d1=max(lsz)-min(lsz)+1
                                d2=max(lsy)-min(lsy)+1
                                p=d1/d2
                                k.append(p)
                                num.append(len(lsx))
                                h.append(d1)
                                g=d1/len(lsx)
                                e.append(g)
                                n=0
                                for i in range(len(lsx)):
                                    q=lsx[i].split(',')
                                    x=int(q[0])
                                    y=int(q[1])
                                    z=int(q[2])
                                    k1=x+1
                                    k2=x-1
                                    k3=z+1
                                    k4=z-1
                                    if 0<k1<=64 and dic2[str(k1)+','+str(y)+','+str(z)]==str(1):
                                        n=n+1
                                    if 0<k2<=64 and dic2[str(k2)+','+str(y)+','+str(z)]==str(1):
                                        n=n+1
                                    if 0<k3<=64 and dic2[str(x)+','+str(y)+','+str(k3)]==str(1):
                                        n=n+1
                                    if 0<k4<=64 and dic2[str(x)+','+str(y)+','+str(k4)]==str(1):
                                        n=n+1
                                zhouchang.append(n)
                                if n>0:
                                    yuan=4*pi*len(lsx)/n**2
                                    yuandu.append(yuan)
                            break
    return k,num,h,e,zhouchang,yuandu
#xz平面 dz/dx  取向因子：dz/dx的大小  核的面积 核的高度 核的高度与面积的比,核的周长，核的圆度

# %%
def hs3(dic):
    m=0
    dic3=dic.copy()
    for i in range(1,500):
        for j in range(1,500):
            for k in range(1,500):
                if dic3[str(i)+','+str(j)+','+str(k)]==str(2):
                    b=k-1
                    c=k+1
                    if 0<b<=500 and dic3[str(i)+','+str(j)+','+str(b)]==str(1):
                        m=m+1
                    if 0<c<=500 and dic3[str(i)+','+str(j)+','+str(c)]==str(1):
                        m=m+1
    return m
#上下截面面积

# %%
def hs4(dic):
    n=0
    dic4=dic.copy()
    for i in range(1,500):
        for j in range(1,500):
            for k in range(1,500):
                if dic[str(i)+','+str(j)+','+str(k)]==str(2):
                    b=i-1
                    c=i+1
                    d=j-1
                    e=j+1
                    if 0<b<=500 and dic4[str(b)+','+str(j)+','+str(k)]==str(1):
                        n=n+1
                    if 0<c<=500 and dic4[str(c)+','+str(j)+','+str(k)]==str(1):
                        n=n+1
                    if 0<d<=500 and dic4[str(i)+','+str(d)+','+str(k)]==str(1):
                        n=n+1
                    if 0<e<=500 and dic4[str(i)+','+str(e)+','+str(k)]==str(1):
                        n=n+1
    return n
#侧面截面面积

# %%
def hs5(dic):
    dic5=dic.copy()
    num=0
    for x in range(1,500):
        for y in range(1,500):
            for z in range(1,500):
                if dic5[str(x)+','+str(y)+','+str(z)]==str(2):
                    num=num+1
    p=num/len(dic)
    n=0
    for x in range(1,500):
        for y in range(1,500):
            m=0
            for z in range(1,500):
                if dic5[str(x)+','+str(y)+','+str(z)]==str(2):
                    m=m+1
            if p<m/500:
                n=n+1
    q=n/500/500
    return q
#优势路径

# %%
def hs6(dic):
    num=0
    dic6=dic.copy()
    for x in range(1,500):
        for y in range(1,500):
            for z in range(1,500):
                if dic6[str(x)+','+str(y)+','+str(z)]==str(2):
                    num=num+1
    p=num/len(dic)
    n=0
    for x in range(1,500):
        for y in range(1,500):
            m=0
            for z in range(1,500):
                if dic6[str(x)+','+str(y)+','+str(z)]==str(2):
                    m=m+1
            if m/500<p*0.5:
                n=n+1
    q=n/500/500
    return q
#最短路径

# %%
def hs7(dic):
    n=0
    dic7=dic.copy()
    for x in range(1,500):
        for y in range(1,500):
            for z in range(1,500):
                if dic7[str(x)+','+str(y)+','+str(z)]==str(2):
                    n=n+1
    n=n/500/500/500
    return n
#PZT体积分数

# %%
def hs8(dic):
    num=0
    dic8=dic.copy()
    for x in range(1,500):
        for z in range(1,500):
            for y in range(1,500):
                if dic8[str(x)+','+str(y)+','+str(z)]==str(2):
                    num=num+1
    p=num/len(dic8)
    T=0
    for x in range(1,500):
        n=0
        for z in range(1,500):
            m=0
            for y in range(1,500):
                if dic8[str(x)+','+str(y)+','+str(z)]==str(2):
                    m=m+1
            n=n+(m-500*p)**2/500
        T=T+n**(1/2)
    return T/500
#通道因子y

# %%
def hs9(dic):
    num=0
    dic9=dic.copy()
    for x in range(1,500):
        for y in range(1,500):
            for z in range(1,500):
                if dic9[str(x)+','+str(y)+','+str(z)]==str(2):
                    num=num+1
    p=num/len(dic9)
    T=0
    for x in range(1,500):
        n=0
        for y in range(1,500):
            m=0
            for z in range(1,500):
                if dic9[str(x)+','+str(y)+','+str(z)]==str(2):
                    m=m+1
            n=n+(m-500*p)**2/500
        T=T+n**(1/2)
    return T/500
#通道因子z

# %%
def hs13(dic):
    num=0
    dic90=dic.copy()
    for z in range(1,500):
        for y in range(1,500):
            for x in range(1,500):
                if dic90[str(x)+','+str(y)+','+str(z)]==str(2):
                    num=num+1
    p=num/len(dic90)
    T=0
    for z in range(1,500):
        n=0
        for y in range(1,500):
            m=0
            for x in range(1,500):
                if dic90[str(x)+','+str(y)+','+str(z)]==str(2):
                    m=m+1
            n=n+(m-500*p)**2/500
        T=T+n**(1/2)
    return T/500
#通道因子x

# %%
def hs10(dic):
    m=0
    n=0
    dic10=dic.copy()
    for x in range(1,500):
        for y in range(1,500):
            for z in range(1,500):
                if dic10[str(x)+','+str(y)+','+str(z)]==str(2):
                    m=m+1
                if dic10[str(x)+','+str(y)+','+str(z)]==str(2) and z>32:
                    n=n+1
    f=n/m
    return f
#PZT 上半部分体积分数

# %%
def hs11(dic):
    n=0
    m=0
    dic11=dic.copy()
    z=500
    for x in range(1,500):
        for y in range(1,500):
            if dic11[str(x)+','+str(y)+','+str(z)]==str(1):
                n=n+1
    n=n/500/500
    return n
#最上面一层PZT的含量

# %%
def hs12(dic):
    dic12=dic.copy()
    n=0
    num=[]
    lsd=[]
    lsbi=[]
    lsv=[]
    lsvs=[]
    qiu=[]
    for x in range(1,500):
        for y in range(1,500):
            for z in range(1,500):
                if dic12[str(x)+','+str(y)+','+str(z)]==str(2):
                    n=n+1
                    m=0
                    lsz=[z]
                    lsx=[str(x)+','+str(y)+','+str(z)]
                    dic12[lsx[m]]=str(3)
                    while dic12[lsx[m]]==str(3):
                        q=lsx[m].split(',')
                        x=int(q[0])
                        y=int(q[1])
                        z=int(q[2])
                        if 0<x+1<=500:
                            a=x+1
                            b=y
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y+1<=500:
                            a=x
                            b=y+1
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z+1<=500:
                            a=x
                            b=y
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<y+1<=500:
                            a=x+1
                            b=y+1
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<y-1<=500:
                            a=x+1
                            b=y-1
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<z+1<=500:
                            a=x+1
                            b=y
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<z-1<=500:
                            a=x+1
                            b=y
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<y+1<=500 and 0<z+1<=500:
                            a=x+1
                            b=y+1
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<y+1<=500 and 0<z-1<=500:
                            a=x+1
                            b=y+1
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<y-1<=500 and 0<z+1<=500:
                            a=x+1
                            b=y-1
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=500 and 0<y-1<=500 and 0<z-1<=500:
                            a=x+1
                            b=y-1
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<y-1<=500 and 0<z+1<=500:
                            a=x-1
                            b=y-1
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<y-1<=500 and 0<z-1<=500:
                            a=x-1
                            b=y-1
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<y+1<=500 and 0<z+1<=500:
                            a=x-1
                            b=y+1
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<y+1<=500 and 0<z-1<=500:
                            a=x-1
                            b=y+1
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y+1<=500 and 0<z+1<=500:
                            a=x
                            b=y+1
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z+1<=500 and 0<y-1<=500:
                            a=x
                            b=y-1
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y+1<=500 and 0<z-1<=500:
                            a=x
                            b=y+1
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z-1<=500 and 0<y-1<=500:
                            a=x
                            b=y-1
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z-1<=500:
                            a=x
                            b=y
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500:
                            a=x-1
                            b=y
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y-1<=500:
                            a=x
                            b=y-1
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<y-1<=500:
                            a=x-1
                            b=y-1
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<y+1<=500:
                            a=x-1
                            b=y+1
                            c=z
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=500 and 0<z-1<=500:
                            a=x-1
                            b=y
                            c=z-1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z+1<=500 and 0<x-1<=500:
                            a=x-1
                            b=y
                            c=z+1
                            if dic12[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic12[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        m=m+1
                        if len(lsx)<m+1:
                            num.append(len(lsx))
                            j=max(lsz)-min(lsz)+1
                            bi=j/len(lsx)
                            lsd.append(j)
                            lsbi.append(bi)
                            v=0
                            for i in range(len(lsx)):
                                q=lsx[i].split(',')
                                x=int(q[0])
                                y=int(q[1])
                                z=int(q[2])
                                k1=x-1
                                k2=x+1
                                k3=y-1
                                k4=y+1
                                k5=z-1
                                k6=z+1
                                if 0<k1<=500 and dic12[str(k1)+','+str(y)+','+str(z)]==str(1):
                                    v=v+1
                                if 0<k2<=500 and dic12[str(k2)+','+str(y)+','+str(z)]==str(1):
                                    v=v+1
                                if 0<k3<=500 and dic12[str(x)+','+str(k3)+','+str(z)]==str(1):
                                    v=v+1
                                if 0<k4<=500 and dic12[str(x)+','+str(k4)+','+str(z)]==str(1):
                                    v=v+1
                                if 0<k5<=500 and dic12[str(x)+','+str(y)+','+str(k5)]==str(1):
                                    v=v+1
                                if 0<k6<=500 and dic12[str(x)+','+str(y)+','+str(k6)]==str(1):
                                    v=v+1
                            lsv.append(v)
                            g=v/len(lsx)
                            lsvs.append(g)
                            qiudu=6*(pi**(1/2))*len(lsx)/(v**(3/2))
                            qiu.append(qiudu)
                            break
    return num,lsd,lsbi,lsv,lsvs,qiu
    #print(n)#孔隙的个数
    #print(num)#孔隙的个数列表
    #big=max(num)
    #small=min(num)
    #p=mean(num)
    #pd=mean(lsbi)
    #print(big)#孔隙的最大值
    #print(small)#孔隙的最小值
#    print(p)#孔隙的平均值
#   print(lsd)#孔隙的高度
#  print(lsbi)#孔隙高度与体积的比值
# print(pd)#平均比值

# %%
from numpy import *
import os
import xlrd
path1='E:'
path2='/daore\dat'
#workBook = xlrd.open_workbook(r'E:\daore\shuju.xls')
#allSheetNames = workBook.sheet_names();
#sheet1Name = workBook.sheet_names()[0];
#sheet1_content1 = workBook.sheet_by_index(0);
#sheet1_content2 = workBook.sheet_by_name('Sheet1');
#d33 = sheet1_content1.col_values(2)[1:11]; # 获取第1列内容
#d31 = sheet1_content1.col_values(2)[1:101]; # 获取第2列内容
#d15 = sheet1_content1.col_values(3)[1:101]; # 获取第3列内容
#K33 = sheet1_content1.col_values(4)[1:101]; # 获取第4列内容
#dh = sheet1_content1.col_values(5)[1:101]; # 获取第5列内容
#FOM = sheet1_content1.col_values(6)[1:101]; # 获取第6列内容
#g33 = sheet1_content1.col_values(7)[1:101]; # 获取第7列内容
ls0=[]
d33=[1]
for i in range(len(d33)):
    if d33[i]== 0:
        ls0.append(i)
ls1=[]
ls2=[]
ls3=[]
ls4=[]
ls5=[]
ls6=[]
ls7=[]
ls8=[]
ls9=[]
ls10=[]
ls11=[]
ls12=[]
ls13=[]
ls14=[]
ls15=[]
ls16=[]
ls17=[]
ls18=[]
ls19=[]
ls20=[]
ls21=[]
ls22=[]
ls23=[]
ls24=[]
ls25=[]
ls26=[]
ls27=[]
ls28=[]
ls29=[]
ls30=[]
ls31=[]
ls32=[]
ls33=[]
ls34=[]
ls151=[]

# %%
for i in range(1,11):
    path3='lcy'+str(i)+'.dat'
    path = os.path.join(path1,path2,path3)
    f=open(path)
    dic={}
    for line in f:
        s = line.strip().split('\t')
        s=s[0]
        s=s.split()
        if len(s)==4:
            b=str(s[0]+','+s[1]+','+s[2])
            c=str(s[3])
            if int(c)==2:
                dic[b]=str(1)
            if int(c)==1:
                dic[b]=str(2)
    f.close()
    #print(' ')
    #print('数据：%s'%i)
    #print(' ') 为了方便查看数据 才写的一个print  整体使用时可以忽略
    dzdy,daxiaoy,gaoduy,hareay,zhouchangy,yuanduy=hs1(dic)
    geshuy=len(daxiaoy)/500
    dzdx,daxiaox,gaodux,hareax,zhouchangx,yuandux=hs2(dic)
    geshux=len(daxiaox)/500
    mianjishangxia=hs3(dic)
    mianjicemian=hs4(dic)
    youshilujing=hs5(dic)
    zuiduanlujing=hs6(dic)
    PZTtiji=hs7(dic)
    tongdaoyinziy=hs8(dic)
    tongdaoyinziz=hs9(dic)
    tongdaoyinzix=hs13(dic)
    yiban=hs10(dic)
    zuishang=hs11(dic)
    num,lsd,lsbi,lsv,lsvs,qiu=hs12(dic)
    keligeshu=len(num)
    big=max(num)
    pinjun=mean(num)
    gaodu=mean(lsd)
    dzdxdy=mean(dzdy)*mean(dzdx)
    pd=mean(lsbi)
    biaomianjipj=mean(lsv)
    bibiaomianjipj=mean(lsvs)
    qiudu=mean(qiu)
    s1=(mianjishangxia)/(500*500*500*PZTtiji)#上下界面面积与体积的比
    s2=(mianjicemian)/(500*500*500*PZTtiji) #侧面界面面积与体积的比
    ls1.append(mean(dzdy))#dz/dy的平均值    平面上
    ls2.append(mean(daxiaoy))# PZT截面上平均大小  平面上
    ls3.append(mean(gaoduy))# 平均高度   平面上
    ls4.append(geshuy)#平均PZT个数 平面上
    ls5.append(mean(dzdx))#dz/dx的平均值    平面上
    ls6.append(mean(daxiaox))# PZT截面上平均大小  平面上
    ls7.append(mean(gaodux))# 平均高度   平面上
    ls8.append(geshux)#平均PZT个数 平面上
    ls9.append(mianjishangxia)# 上下界面面积
    ls10.append(mianjicemian) #侧面界面面积
    ls11.append(youshilujing) #优势路径
    ls12.append(zuiduanlujing)#最短路径
    ls13.append(PZTtiji) #PZT体积分数
    ls14.append(tongdaoyinziy) #通道因子y
    ls15.append(tongdaoyinziz) #通道因子z
    ls151.append(tongdaoyinzix) #通道因子x
    ls16.append(yiban) # 上半部分PZT体积分数
    ls17.append(zuishang) #最上面一层PZT的含量
    ls18.append(keligeshu) # PZT颗粒个数
    ls19.append(big) #最大颗粒的体积
    ls20.append(pinjun) #颗粒平均大小
    ls21.append(gaodu)#颗粒平均高度
    ls22.append(pd) #颗粒高度与体积的平均比值
    ls23.append(dzdxdy)# 取向因子x 与y 的乘积
    ls24.append(mean(hareay)) #yz 截面 核高度与面积之比
    ls25.append(mean(hareax)) #xz 截面 核高度与面积之比
    ls26.append(mean(zhouchangy)) #yz 截面 核的周长
    ls27.append(mean(zhouchangx)) #xz 截面 核的周长
    ls28.append(mean(yuanduy))   #yz 截面 核的圆度
    ls29.append(mean(yuandux))   #xz 截面 核的圆度
    ls30.append(s1) # 上下界面面积与体积的比
    ls31.append(s2)  #左右界面 面积与体积的比
    ls32.append(biaomianjipj)  #颗粒平均表面积
    ls33.append(bibiaomianjipj) #颗粒平均比表面积
    ls34.append(qiudu)   #球度
j=0
for i in range(len(ls0)):
    a=ls0[i]
    a=a-j
    j=j+1
    d33.pop(a)
    #d31.pop(a)
    #d15.pop(a)
    #K33.pop(a)
    #dh.pop(a)
    #FOM.pop(a)
    #g33.pop(a)
    ls1.pop(a)
    ls2.pop(a)
    ls3.pop(a)
    ls4.pop(a)
    ls5.pop(a)
    ls6.pop(a)
    ls7.pop(a)
    ls8.pop(a)
    ls9.pop(a)
    ls10.pop(a)
    ls11.pop(a)
    ls12.pop(a)
    ls13.pop(a)
    ls14.pop(a)
    ls15.pop(a)
    ls16.pop(a)
    ls17.pop(a)
    ls18.pop(a)
    ls19.pop(a)
    ls20.pop(a)
    ls21.pop(a)
    ls22.pop(a)
    ls23.pop(a)
    ls24.pop(a)
    ls25.pop(a)
    ls26.pop(a)
    ls27.pop(a)
    ls28.pop(a)
    ls29.pop(a)
    ls30.pop(a)
    ls31.pop(a)
    ls32.pop(a)
    ls33.pop(a)
    ls34.pop(a)
    ls151.pop(a)
#除去数据中失败的数据
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 21
#      17 f.close()
#      18 #print(' ')
#      19 #print('数据：%s'%i)
#      20 #print(' ') 为了方便查看数据 才写的一个print  整体使用时可以忽略
# ---> 21 dzdy,daxiaoy,gaoduy,hareay,zhouchangy,yuanduy=hs1(dic)
#      22 geshuy=len(daxiaoy)/500
#      23 dzdx,daxiaox,gaodux,hareax,zhouchangx,yuandux=hs2(dic)
#
# Cell In[73], line 28, in hs1(dic)
#      26 b=y+1
#      27 c=z
# ---> 28 if dic1[str(a)+','+str(b)+','+str(c)]==str(2):
#      29     dic1[str(a)+','+str(b)+','+str(c)]=str(3)
#      30     lsx.append(str(a)+','+str(b)+','+str(c))
#
# KeyError: '2,2,17'

# %%
import pandas as pd
ls=zip(ls1,ls2,ls3,ls4,ls5,ls6,ls7,ls8,ls9,ls10,ls11,ls12,ls13,ls14,ls15,ls151,ls16,ls17,ls18,ls19,ls20,ls21,ls22,ls23,ls24,ls25,ls26,ls27,ls28,ls29,ls30,ls31,ls32,ls33,ls34)
name=['取向因子y','平面聚集度y','聚集高度y','平面聚集数y','取向因子x','平面聚集度x','聚集高度x','平面聚集数x','界面垂直因子','界面平行因子','优势路径','最短路径','PZT体积分数','通道因子y','通道因子z','通道因子x','优势分布','受力因子','聚集数','最大聚集度','平均聚集度','颗粒平均高度','竖向因子','取向因子','高度与面积之比y','高度与面积之比x','周长y','周长x','圆度y','圆度x','上下界面面积与体积之比','侧面界面面积与体积之比','颗粒平均表面积','颗粒平均比表面积','球度']
test=pd.DataFrame(columns=name,data=ls)
test.to_csv('E:\daore\miaoshufu1125.csv',encoding='utf-8-sig')
