# %%
from numpy import *
import os
import xlrd
path1='E:'
path2='\structure'
for i in range(1,2):
    path3=str(i)+'.dat'
    path = os.path.join(path1,path2,path3)
    f=open(path)
    dic={}
    for line in f:
        s = line.strip().split('\t')
        s=s[0]
        s=s.split()
        if len(s)==4:
            b=str(str(int(float(s[0])))+','+str(int(float(s[1])))+','+str(int(float(s[2]))))
            c=str(str(int(float(s[3]))))
            dic[b]=c
    f.close()
    n=0
    num=[]
    lsd=[]
    lsbi=[]
    for x in range(1,101):
        for y in range(1,101):
            for z in range(1,101):
                if dic[str(x)+','+str(y)+','+str(z)]==str(2):
                    n=n+1
                    m=0
                    lsz=[z]
                    lsx=[str(x)+','+str(y)+','+str(z)]
                    dic[lsx[m]]=str(3)
                    while dic[lsx[m]]==str(3):
                        q=lsx[m].split(',')
                        x=int(q[0])
                        y=int(q[1])
                        z=int(q[2])
                        if 0<x+1<=100:
                            a=x+1
                            b=y
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y+1<=100:
                            a=x
                            b=y+1
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z+1<=100:
                            a=x
                            b=y
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<y+1<=100:
                            a=x+1
                            b=y+1
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<y-1<=100:
                            a=x+1
                            b=y-1
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<z+1<=100:
                            a=x+1
                            b=y
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<z-1<=100:
                            a=x+1
                            b=y
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<y+1<=100 and 0<z+1<=100:
                            a=x+1
                            b=y+1
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<y+1<=100 and 0<z-1<=100:
                            a=x+1
                            b=y+1
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<y-1<=100 and 0<z+1<=100:
                            a=x+1
                            b=y-1
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x+1<=100 and 0<y-1<=100 and 0<z-1<=100:
                            a=x+1
                            b=y-1
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<y-1<=100 and 0<z+1<=100:
                            a=x-1
                            b=y-1
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<y-1<=100 and 0<z-1<=100:
                            a=x-1
                            b=y-1
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<y+1<=100 and 0<z+1<=100:
                            a=x-1
                            b=y+1
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<y+1<=100 and 0<z-1<=100:
                            a=x-1
                            b=y+1
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y+1<=100 and 0<z+1<=100:
                            a=x
                            b=y+1
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z+1<=100 and 0<y-1<=100:
                            a=x
                            b=y-1
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y+1<=100 and 0<z-1<=100:
                            a=x
                            b=y+1
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z-1<=100 and 0<y-1<=100:
                            a=x
                            b=y-1
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z-1<=100:
                            a=x
                            b=y
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100:
                            a=x-1
                            b=y
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<y-1<=100:
                            a=x
                            b=y-1
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<y-1<=100:
                            a=x-1
                            b=y-1
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<y+1<=100:
                            a=x-1
                            b=y+1
                            c=z
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<x-1<=100 and 0<z-1<=100:
                            a=x-1
                            b=y
                            c=z-1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        if 0<z+1<=100 and 0<x-1<=100:
                            a=x-1
                            b=y
                            c=z+1
                            if dic[str(a)+','+str(b)+','+str(c)]==str(2):
                                dic[str(a)+','+str(b)+','+str(c)]=str(3)
                                lsx.append(str(a)+','+str(b)+','+str(c))
                                lsz.append(c)
                        m=m+1
                        if len(lsx)<m+1:
                            num.append(len(lsx))
                            j=max(lsz)-min(lsz)+1
                            bi=j/len(lsx)
                            lsd.append(j)
                            lsbi.append(bi)
                            break
    print(' ')
    print('数据：%s'%i)
    print(' ')
    print(n)#孔隙的个数
    print(num)#孔隙的个数列表
    big=max(num)
    small=min(num)
    p=mean(num)
    pd=mean(lsbi)
    print(big)#孔隙的最大值
    print(small)#孔隙的最小值
    print(p)#孔隙的平均值
    #print(lsd)#孔隙的高度
    #print(lsbi)#孔隙高度与体积的比值
    print(pd)#平均比值
# Out:
#
# 数据：1
#
# 4
# [1, 258766, 55, 52]
# 258766
# 1
# 64718.5
# 0.3110231858099623

# %%
# Out:
# 1
